# %%
import utils
import cv2

img = cv2.imread('/home/dan/Downloads/poulespng/poule-2.pdf.png', cv2.IMREAD_UNCHANGED)
img_ref = cv2.imread('data/pngs/poule-back-page-tmpl-no-alpha.png', cv2.IMREAD_UNCHANGED)

# utils.disp_image(img, cv2.COLOR_BGR2RGB)
# utils.disp_image(img_ref, cv2.COLOR_BGR2RGB)

img_reg, h = utils.alignImages(img, img_ref, max_features=1000, match_ratio=0.15)

utils.disp_image(img_reg, cv2.COLOR_BGR2RGB)
